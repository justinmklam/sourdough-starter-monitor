# %%
import matplotlib
import matplotlib.pyplot as plt

from skimage import data, io
from skimage.filters import try_all_threshold

# %% [markdown]
# # Test Image

# %%
img = io.imread('2018-05-31 Levain Timelapse/2018-05-31_15-07-13_(0).jpg', 
                as_grey=True)

img = img[0:1000, 650:1100]
plt.imshow(img, cmap='gray')

# %%
fig, ax = try_all_threshold(img, figsize=(10, 8), verbose=False)
plt.show()

# %% [markdown]
# Looks like Yen threshold is the best so far.
# ## Yen Threshold

# %%
from skimage.filters import threshold_yen

# %%
thresh = threshold_yen(img, nbins=5)
binary = img < thresh

fig, axes = plt.subplots(ncols=2, figsize=(8, 3))
ax = axes.ravel()

ax[0].imshow(img, cmap=plt.cm.gray)
ax[0].set_title('Original image')

ax[1].imshow(binary, cmap=plt.cm.gray)
ax[1].set_title('Result')
# Out:
# Text(0.5,1,'Result')

# %% [markdown]
# ## Measure Region Props

# %%
from skimage.draw import ellipse
from skimage.measure import label, regionprops
from skimage.transform import rotate

# %%
label_img = label(binary)
regions = regionprops(label_img)

fig, ax = plt.subplots()
ax.imshow(binary, cmap=plt.cm.gray)

for props in regions:
    y0, x0 = props.centroid
    orientation = props.orientation
    
    minr, minc, maxr, maxc = props.bbox
    bx = (minc, maxc, maxc, minc, minc)
    by = (minr, minr, maxr, maxr, minr)
    
    area = (maxc-minc)*(maxr-minr)
    
    if area >= 40000:
        ax.plot(bx, by, '-b', linewidth=2.5)
        ax.plot(x0, y0, 'ro')
        print(minr)

# ax.axis((0, 600, 600, 0))
plt.show()
# Out:
# 763

# %% [markdown]
# ## Automated Analysis

# %%
# %load_ext autoreload

# %autoreload 2

import timelapse_analysis as ta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ta.test_image('2018-05-31 Levain Timelapse/2018-05-31_15-07-13_(0).jpg', crop_area=[0, 1000, 650, 1100]);
# Out:
# 758
# 1000 450

# %%
df_531 = ta.analyze_image('2018-05-31 Levain Timelapse')
# Out:
# 242 1000

# %%
ta.test_image('2018-05-31 Levain Timelapse/2018-05-31_21-17-07_(74).jpg', crop_area=[0, 1000, 650, 1100]);
# Out:
# 509
# 1000 450

# %%
ta.test_image('2018-05-31 Levain Timelapse/2018-05-31_23-02-04_(95).jpg', crop_area=[0, 1000, 650, 1100], min_area=40000);
# Out:
# Height:  586
# 1000 450

# %%
df_531
# Out:
#                                                  File  Height  Time  \
# 0   2018-05-31 Levain Timelapse\2018-05-31_15-07-1...     758     0
# 1   2018-05-31 Levain Timelapse\2018-05-31_15-12-1...     759     5
# 2   2018-05-31 Levain Timelapse\2018-05-31_15-17-1...     760    10
# 3   2018-05-31 Levain Timelapse\2018-05-31_15-22-1...     763    15
# 4   2018-05-31 Levain Timelapse\2018-05-31_15-27-1...     760    20
# 5   2018-05-31 Levain Timelapse\2018-05-31_15-32-1...     758    25
# 6   2018-05-31 Levain Timelapse\2018-05-31_15-37-1...     759    30
# 7   2018-05-31 Levain Timelapse\2018-05-31_15-42-1...     761    35
# 8   2018-05-31 Levain Timelapse\2018-05-31_15-47-1...     760    40
# 9   2018-05-31 Levain Timelapse\2018-05-31_15-52-1...     761    45
# 10  2018-05-31 Levain Timelapse\2018-05-31_15-57-1...     760    50
# 11  2018-05-31 Levain Timelapse\2018-05-31_16-02-1...     761    55
# 12  2018-05-31 Levain Timelapse\2018-05-31_16-07-1...     759    60
# 93  2018-05-31 Levain Timelapse\2018-05-31_22-52-0...     584   465
# 94  2018-05-31 Levain Timelapse\2018-05-31_22-57-0...     586   470
# 95  2018-05-31 Levain Timelapse\2018-05-31_23-02-0...     586   475
#
#     Height Normalized
# 0            0.000000
# 1            0.004132
# 2            0.008264
# 3            0.020661
# 4            0.008264
# 5            0.000000
# 6            0.004132
# 7            0.012397
# 8            0.008264
# 9            0.012397
# 10           0.008264
# 11           0.012397
# 12           0.004132
# 13           0.008264
# 14          -0.020661
# 15          -0.020661
# 16          -0.053719
# 17          -0.049587
# 18          -0.305785
# 19          -0.190083
# 20          -0.173554
# 21          -0.173554
# 22          -0.239669
# 23          -0.247934
# 24          -0.235537
# 25          -0.185950
# 26          -0.475207
# 27          -0.450413
# 28          -0.421488
# 29          -0.384298
# ..                ...
# 66          -1.235537
# 67          -1.194215
# 68          -1.123967
# 69          -1.090909
# 70          -1.074380
# 71          -1.061983
# 72          -1.049587
# 73          -1.041322
# 74          -1.028926
# 75          -1.008264
# 76          -0.946281
# 77          -0.904959
# 78          -0.888430
# 79          -0.847107
# 80          -0.830579
# 81          -0.826446
# 82          -0.818182
# 83          -0.818182
# 84          -0.789256
# 85          -0.797521
# 86          -0.785124
# 87          -0.772727
# 88          -0.764463
# 89          -0.760331
# 90          -0.752066
# 91          -0.735537
# 92          -0.723140
# 93          -0.719008
# 94          -0.710744
# 95          -0.710744
#
# [96 rows x 4 columns]

# %% [markdown]
# # 2018-05-31 Levain Timelapse 2

# %%
ta.load_image('2018-05-31 Levain Timelapse 2/2018-05-31_23-27-03_(100).jpg', crop_area=[100, 950, 350, 700], show_img=True);

# %%
img = io.imread('2018-05-31 Levain Timelapse 2/2018-05-31_23-27-03_(100).jpg', as_grey=True)
fig, ax = try_all_threshold(img, figsize=(10, 8), verbose=False)
plt.show()

# %%
df = ta.analyze_image('2018-05-31 Levain Timelapse 2', crop_area=[100, 950, 350, 700])
# Out:
# 301 850

# %% [markdown]
# # 2018-05-29 Levain Timelapse
# ## Left Jar

# %%
ta.load_image('2018-05-29 Levain Timelapse/2018-05-29_05-34-25_(1).jpg', crop_area=[100, 950, 300, 700], show_img=True);

# %%
df_529left = ta.analyze_image('2018-05-29 Levain Timelapse', crop_area=[100, 950, 300, 700])
# Out:
# 361 850

# %% [markdown]
# ## Right Jar

# %%
ta.test_image('2018-05-29 Levain Timelapse/2018-05-29_05-34-25_(1).jpg', crop_area=[100, 950, 780, 1300]);
# Out:
# 537
# 850 520

# %%
df_529 = ta.analyze_image('2018-05-29 Levain Timelapse', crop_area=[100, 950, 750, 1300])
# Out:
# 317 850

# %%
ta.test_image('2018-05-29 Levain Timelapse/2018-05-29_05-34-25_(1).jpg', crop_area=[100, 950, 780, 1300], min_area=10000);
# Out:
# 537
# 850 520

# %%
ta.test_image('2018-05-29 Levain Timelapse/2018-05-29_09-49-23_(52).jpg', crop_area=[100, 950, 780, 1300], min_area=10000);
# Out:
# 362

# %% [markdown]
# # Comparison

# %%
plt.plot(df_529left['Time'], df_529left['Height Normalized'], label='2018-05-29')
plt.plot(df_531['Time'], df_531['Height Normalized'], label='2018-05-31')
plt.plot(df_529['Time'], df_529['Height Normalized'], label='2018-05-29')
plt.plot(df['Time'], df['Height Normalized'], label='2018-05-31 (2nd)')

plt.legend()
